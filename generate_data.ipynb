# %% [markdown]
# # COMP 353 Project: Group 3
# This python Notebook contains code to generate large amounts of test data, and
# populate the database. Assuming the a MySQL database is running at: `mysql://root:@localhost:3306/warmup`,
# then the notebook can be run top-to-bottom to create tables and populate the DB.

# %%
# !pip install Faker mysqlclient pandas sqlalchemy
# Out:
# Requirement already satisfied: Faker in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (26.0.0)
# Requirement already satisfied: mysqlclient in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (2.2.4)
# Requirement already satisfied: pandas in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: sqlalchemy in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (2.0.31)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (from Faker) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (from pandas) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (from sqlalchemy) (3.0.3)
# Requirement already satisfied: six>=1.5 in c:\users\drewa\onedrive\documents\school\comp353\groupproject\.venv\lib\site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Faker contains methods for generating realistic random data.
from faker import Faker
from faker.providers import (
    person,
    profile,
    address,
    python,
    internet,
    lorem,
    DynamicProvider,
)

# %%
database_uri = "mysql://tnc353_1:f5hnR6VD@tnc353.encs.concordia.ca:3306/tnc353_1"

# %%
# Define some values to use for data generation:
quebec_cities = [
    "Montreal",
    "Quebec City",
    "Laval",
    "Gatineau",
    "Longueuil",
    "Sherbrooke",
    "Saguenay",
    "Lévis",
    "Trois-Rivières",
    "Terrebonne",
    "Saint-Jean-sur-Richelieu",
    "Repentigny",
    "Drummondville",
    "Saint-Jérôme",
    "Granby",
    "Blainville",
    "Saint-Hyacinthe",
    "Shawinigan",
    "Dollard-des-Ormeaux",
    "Rimouski",
    "Châteauguay",
    "Brossard",
    "Mirabel",
    "Saint-Georges",
    "Victoriaville",
    "Val-d'Or",
    "Rouyn-Noranda",
    "Sorel-Tracy",
    "Boucherville",
    "Salaberry-de-Valleyfield",
]
soccer_roles = ["goalkeeper", "defender", "midfielder", "forward", "other"]

# %%
# Initialize faker instance with required providers:
fake = Faker("en_CA")
fake.add_provider([person, profile, address, python, internet, lorem])
fake.add_provider(DynamicProvider("quebec_city", elements=quebec_cities))

# %%
# Generate One Location Per City:
locations = (
    pd.DataFrame(
        [
            {
                "phoneNumber": f"514555{str(fake.unique.random_int(0, 10000)).zfill(4)}",
                "civicNumber": fake.building_number(),
                "province": "QC",
                "postalCode": fake.postalcode_in_province("QC").replace(' ', ''),
                "city": city,
                "capacity": fake.pyint(min_value=50, max_value=900),
                "name": f"{city} Soccer Club",
                "webAddress": f"{city.replace(' ', '-').replace('\'', '').lower()}.yscm.ca",
                "type": "Branch",
            }
            for city in quebec_cities
        ]
    )
    .drop_duplicates("name")
    .reset_index(drop=True)
)
locations.index.name = "locationID"
locations.at[fake.random.randint(0, len(locations)), "type"] = "Head"
locations.index = locations.index + 1
locations = locations.reset_index().to_dict('records')
locations
# Out:
# [{'locationID': 1,
#   'phoneNumber': '5145550016',
#   'civicNumber': '9054',
#   'province': 'QC',
#   'postalCode': 'J9T8X3',
#   'city': 'Montreal',
#   'capacity': 112,
#   'name': 'Montreal Soccer Club',
#   'webAddress': 'montreal.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 2,
#   'phoneNumber': '5145552841',
#   'civicNumber': '11926',
#   'province': 'QC',
#   'postalCode': 'H4T1A2',
#   'city': 'Quebec City',
#   'capacity': 281,
#   'name': 'Quebec City Soccer Club',
#   'webAddress': 'quebec-city.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 3,
#   'phoneNumber': '5145558262',
#   'civicNumber': '89089',
#   'province': 'QC',
#   'postalCode': 'H1J7B6',
#   'city': 'Laval',
#   'capacity': 209,
#   'name': 'Laval Soccer Club',
#   'webAddress': 'laval.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 4,
#   'phoneNumber': '5145557912',
#   'civicNumber': '6757',
#   'province': 'QC',
#   'postalCode': 'H7E3R1',
#   'city': 'Gatineau',
#   'capacity': 807,
#   'name': 'Gatineau Soccer Club',
#   'webAddress': 'gatineau.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 5,
#   'phoneNumber': '5145556973',
#   'civicNumber': '309',
#   'province': 'QC',
#   'postalCode': 'G4M4J7',
#   'city': 'Longueuil',
#   'capacity': 698,
#   'name': 'Longueuil Soccer Club',
#   'webAddress': 'longueuil.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 6,
#   'phoneNumber': '5145557582',
#   'civicNumber': '6043',
#   'province': 'QC',
#   'postalCode': 'H8N5X7',
#   'city': 'Sherbrooke',
#   'capacity': 626,
#   'name': 'Sherbrooke Soccer Club',
#   'webAddress': 'sherbrooke.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 7,
#   'phoneNumber': '5145556878',
#   'civicNumber': '05582',
#   'province': 'QC',
#   'postalCode': 'H7N4X4',
#   'city': 'Saguenay',
#   'capacity': 232,
#   'name': 'Saguenay Soccer Club',
#   'webAddress': 'saguenay.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 8,
#   'phoneNumber': '5145554089',
#   'civicNumber': '90330',
#   'province': 'QC',
#   'postalCode': 'H4T2H4',
#   'city': 'Lévis',
#   'capacity': 884,
#   'name': 'Lévis Soccer Club',
#   'webAddress': 'lévis.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 9,
#   'phoneNumber': '5145556208',
#   'civicNumber': '9995',
#   'province': 'QC',
#   'postalCode': 'J4G9S9',
#   'city': 'Trois-Rivières',
#   'capacity': 246,
#   'name': 'Trois-Rivières Soccer Club',
#   'webAddress': 'trois-rivières.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 10,
#   'phoneNumber': '5145559581',
#   'civicNumber': '140',
#   'province': 'QC',
#   'postalCode': 'J5M5K3',
#   'city': 'Terrebonne',
#   'capacity': 473,
#   'name': 'Terrebonne Soccer Club',
#   'webAddress': 'terrebonne.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 11,
#   'phoneNumber': '5145550573',
#   'civicNumber': '4237',
#   'province': 'QC',
#   'postalCode': 'H6R8L7',
#   'city': 'Saint-Jean-sur-Richelieu',
#   'capacity': 53,
#   'name': 'Saint-Jean-sur-Richelieu Soccer Club',
#   'webAddress': 'saint-jean-sur-richelieu.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 12,
#   'phoneNumber': '5145553986',
#   'civicNumber': '37726',
#   'province': 'QC',
#   'postalCode': 'J7J5Y1',
#   'city': 'Repentigny',
#   'capacity': 382,
#   'name': 'Repentigny Soccer Club',
#   'webAddress': 'repentigny.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 13,
#   'phoneNumber': '5145552144',
#   'civicNumber': '848',
#   'province': 'QC',
#   'postalCode': 'G7E6V9',
#   'city': 'Drummondville',
#   'capacity': 526,
#   'name': 'Drummondville Soccer Club',
#   'webAddress': 'drummondville.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 14,
#   'phoneNumber': '5145555815',
#   'civicNumber': '2522',
#   'province': 'QC',
#   'postalCode': 'H1K3E9',
#   'city': 'Saint-Jérôme',
#   'capacity': 723,
#   'name': 'Saint-Jérôme Soccer Club',
#   'webAddress': 'saint-jérôme.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 15,
#   'phoneNumber': '5145550252',
#   'civicNumber': '922',
#   'province': 'QC',
#   'postalCode': 'G1K9S6',
#   'city': 'Granby',
#   'capacity': 372,
#   'name': 'Granby Soccer Club',
#   'webAddress': 'granby.yscm.ca',
#   'type': 'Head'},
#  {'locationID': 16,
#   'phoneNumber': '5145555263',
#   'civicNumber': '41287',
#   'province': 'QC',
#   'postalCode': 'J7Y3Y1',
#   'city': 'Blainville',
#   'capacity': 711,
#   'name': 'Blainville Soccer Club',
#   'webAddress': 'blainville.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 17,
#   'phoneNumber': '5145555856',
#   'civicNumber': '181',
#   'province': 'QC',
#   'postalCode': 'J2Y1M5',
#   'city': 'Saint-Hyacinthe',
#   'capacity': 791,
#   'name': 'Saint-Hyacinthe Soccer Club',
#   'webAddress': 'saint-hyacinthe.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 18,
#   'phoneNumber': '5145554062',
#   'civicNumber': '372',
#   'province': 'QC',
#   'postalCode': 'J2H5L8',
#   'city': 'Shawinigan',
#   'capacity': 846,
#   'name': 'Shawinigan Soccer Club',
#   'webAddress': 'shawinigan.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 19,
#   'phoneNumber': '5145553120',
#   'civicNumber': '5307',
#   'province': 'QC',
#   'postalCode': 'J8E3B1',
#   'city': 'Dollard-des-Ormeaux',
#   'capacity': 294,
#   'name': 'Dollard-des-Ormeaux Soccer Club',
#   'webAddress': 'dollard-des-ormeaux.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 20,
#   'phoneNumber': '5145554885',
#   'civicNumber': '686',
#   'province': 'QC',
#   'postalCode': 'G2A8N9',
#   'city': 'Rimouski',
#   'capacity': 231,
#   'name': 'Rimouski Soccer Club',
#   'webAddress': 'rimouski.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 21,
#   'phoneNumber': '5145550883',
#   'civicNumber': '358',
#   'province': 'QC',
#   'postalCode': 'J8H8N9',
#   'city': 'Châteauguay',
#   'capacity': 626,
#   'name': 'Châteauguay Soccer Club',
#   'webAddress': 'châteauguay.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 22,
#   'phoneNumber': '5145559803',
#   'civicNumber': '4765',
#   'province': 'QC',
#   'postalCode': 'J8H1A6',
#   'city': 'Brossard',
#   'capacity': 565,
#   'name': 'Brossard Soccer Club',
#   'webAddress': 'brossard.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 23,
#   'phoneNumber': '5145556764',
#   'civicNumber': '13667',
#   'province': 'QC',
#   'postalCode': 'G9E2C5',
#   'city': 'Mirabel',
#   'capacity': 650,
#   'name': 'Mirabel Soccer Club',
#   'webAddress': 'mirabel.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 24,
#   'phoneNumber': '5145554796',
#   'civicNumber': '81169',
#   'province': 'QC',
#   'postalCode': 'J5N9C4',
#   'city': 'Saint-Georges',
#   'capacity': 104,
#   'name': 'Saint-Georges Soccer Club',
#   'webAddress': 'saint-georges.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 25,
#   'phoneNumber': '5145552343',
#   'civicNumber': '6864',
#   'province': 'QC',
#   'postalCode': 'H9V9L9',
#   'city': 'Victoriaville',
#   'capacity': 597,
#   'name': 'Victoriaville Soccer Club',
#   'webAddress': 'victoriaville.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 26,
#   'phoneNumber': '5145554745',
#   'civicNumber': '25445',
#   'province': 'QC',
#   'postalCode': 'H5S1M3',
#   'city': "Val-d'Or",
#   'capacity': 266,
#   'name': "Val-d'Or Soccer Club",
#   'webAddress': 'val-dor.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 27,
#   'phoneNumber': '5145554418',
#   'civicNumber': '26801',
#   'province': 'QC',
#   'postalCode': 'J7S6Y4',
#   'city': 'Rouyn-Noranda',
#   'capacity': 529,
#   'name': 'Rouyn-Noranda Soccer Club',
#   'webAddress': 'rouyn-noranda.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 28,
#   'phoneNumber': '5145557539',
#   'civicNumber': '05590',
#   'province': 'QC',
#   'postalCode': 'J8V7G9',
#   'city': 'Sorel-Tracy',
#   'capacity': 474,
#   'name': 'Sorel-Tracy Soccer Club',
#   'webAddress': 'sorel-tracy.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 29,
#   'phoneNumber': '5145551390',
#   'civicNumber': '4024',
#   'province': 'QC',
#   'postalCode': 'G9V5S8',
#   'city': 'Boucherville',
#   'capacity': 357,
#   'name': 'Boucherville Soccer Club',
#   'webAddress': 'boucherville.yscm.ca',
#   'type': 'Branch'},
#  {'locationID': 30,
#   'phoneNumber': '5145553306',
#   'civicNumber': '04318',
#   'province': 'QC',
#   'postalCode': 'J5A7S5',
#   'city': 'Salaberry-de-Valleyfield',
#   'capacity': 384,
#   'name': 'Salaberry-de-Valleyfield Soccer Club',
#   'webAddress': 'salaberry-de-valleyfield.yscm.ca',
#   'type': 'Branch'}]

# %%
#Personnel
persons = []
personnel = []
for location in locations:
    # General Manager
    persons.append(dict(
        personID=len(persons) + 1,
        firstName=fake.first_name(),
        lastName=fake.last_name(),
        emailAddress=fake.email(),
        telephoneNumber=f"514555{str(fake.unique.random_int(0, 10000)).zfill(4)}",
        dateOfBirth=pd.to_datetime(fake.date_of_birth(minimum_age=16)),
        gender=fake.random.choice(("m", "f")),
        medicareCardNumber=fake.unique.pystr_format("????###########"),
        sin=fake.unique.ssn().replace(" ", ""),
        civicNumber=fake.building_number(),
        province="QC",
        postalCode=fake.postalcode_in_province("QC").replace(' ', ''),
        city=location['city']
    ))
    personnel.append(dict(
        locationID=location['locationID'],
        personID=len(persons),
        startDate=fake.date_between(start_date="-20y", end_date="-3y"),
        endDate=pd.NaT,
        role="Administrator",
        mandate="Salary",
        isGeneralManager=True
    ))
    for _ in range(fake.random_int(2, 7)):
        persons.append(dict(
            personID=len(persons) + 1,
            firstName=fake.first_name(),
            lastName=fake.last_name(),
            emailAddress=fake.email(),
            telephoneNumber=f"514555{str(fake.unique.random_int(0, 10000)).zfill(4)}",
            dateOfBirth=pd.to_datetime(fake.date_of_birth(minimum_age=16)),
            gender=fake.random.choice(("m", "f")),
            medicareCardNumber=fake.unique.pystr_format("????###########"),
            sin=fake.unique.ssn().replace(" ", ""),
            civicNumber=fake.building_number(),
            province="QC",
            postalCode=fake.postalcode_in_province("QC").replace(' ', ''),
            city=location['city']
        ))
        personnel.append(dict(
            locationID=location['locationID'],
            personID=len(persons),
            startDate=fake.date_between(start_date="-20y", end_date="-3y"),
            endDate=pd.NaT,
            role=fake.random.choice(('Administrator', 'Trainer', 'Other')),
            mandate=fake.random.choice(('Volunteer', 'Salary')),
            isGeneralManager=False
        ))

# past_jobs = []
# for job in personnel:
#     sdate = fake.date_between(start_date="-30y", end_date=job['startDate'])
#     role = fake.random.choice(('Administrator', 'Trainer', 'Other'))
#     past_jobs.append(dict(
#         locationID=fake.random_int(1, len(locations)),
#         personID=job['personID'],
#         startDate=sdate,
#         endDate=fake.date_between(start_date=sdate, end_date=job['startDate']),
#         role=role,
#         mandate=fake.random.choice(('Volunteer', 'Salary')),
#         isGeneralManager=False
#     ))
# personnel += past_jobs
len(personnel)
# Out:
# 178

# %%
# Generate random members:
parents = fake.random_choices(persons, 50)
new_parents = []
for location in locations:
    for _ in range(fake.random_int(1, 10)):
        persons.append(
            dict(
                personID=len(persons) + 1,
                firstName=fake.first_name(),
                lastName=fake.last_name(),
                emailAddress=fake.email(),
                telephoneNumber=f"514555{str(fake.unique.random_int(0, 10000)).zfill(4)}",
                dateOfBirth=pd.to_datetime(fake.date_of_birth(minimum_age=16)),
                gender=fake.random.choice(("m", "f")),
                medicareCardNumber=fake.unique.pystr_format("????###########"),
                sin=fake.unique.ssn().replace(" ", ""),
                civicNumber=fake.building_number(),
                province="QC",
                postalCode=fake.postalcode_in_province("QC").replace(' ', ''),
                city=location['city']
            )
        )
parents += new_parents
len(persons), len(parents)
# Out:
# (292, 50)

# %%
clubMembers = []
relatives = []
memberLocations = []
for parent in parents:
    if parent['gender'] == 'm':
        rel = fake.random.choice(('Father', 'GrandFather', 'Tutor', 'Partner', 'Friend'))
    elif parent['gender'] == 'f':
        rel = fake.random.choice(('Mother', 'GrandMother', 'Tutor', 'Partner', 'Friend'))
    
    p = next(filter(lambda x: x['personID'] == parent['personID'], personnel), None)
    if p:
        loc = dict(
            personID=parent['personID'],
            locationID=p['locationID'],
            startDate=p['startDate'],
            endDate=p['endDate']
        )
    else:
        loc = dict(
            personID=parent['personID'],
            locationID=fake.random_int(1, len(locations)),
            startDate=fake.date_between(start_date="-10y", end_date="-1y"),
            endDate=pd.NaT
        )
    
    memberLocations.append(loc)

    for _ in range(fake.random_int(0, 5)):
        child = dict(
            personID=len(persons) + 1,
            firstName=fake.first_name(),
            lastName=fake.last_name(),
            emailAddress=parent['emailAddress'],
            telephoneNumber=parent['telephoneNumber'],
            dateOfBirth=pd.to_datetime(fake.date_of_birth(minimum_age=4, maximum_age=10)),
            gender=fake.random.choice(("m", "f")),
            medicareCardNumber=fake.unique.pystr_format("????###########"),
            sin=fake.unique.ssn().replace(" ", ""),
            civicNumber=parent['civicNumber'],
            province="QC",
            postalCode=parent['postalCode'],
            city=parent['city']
        )
        relatives.append(dict(
            clubMemberID=child['personID'],
            relativeID=parent['personID'],
            relationship=rel  
        ))
        clubMembers.append(dict(
            clubMemberID=child['personID'],
            guardianID=parent['personID'],
            startDate=loc['startDate'],
            priority=0
        ))
        persons.append(child)
        cloc = dict(loc)
        cloc['personID'] = child['personID']
        memberLocations.append(cloc)
for relationship in list(relatives):
    for _ in range(fake.random_int(0, 3)):
        idx = (relationship['relativeID'] + fake.random_int(1, len(parents) - 1)) % len(parents)
        parent = parents[idx]
        if parent['gender'] == 'm':
            rel = fake.random.choice(list(set(('Father', 'GrandFather', 'Tutor', 'Partner', 'Friend')) - {relationship['relationship']}))
        elif parent['gender'] == 'f':
            rel = fake.random.choice(list(set(('Mother', 'GrandMother', 'Tutor', 'Partner', 'Friend')) - {relationship['relationship']}))
        relatives.append(dict(
            clubMemberID=child['personID'],
            relativeID=parent['personID'],
            relationship=rel
        ))
        if fake.random_int(0, 3) == 0:
            clubMembers.append(dict(
                clubMemberID=child['personID'],
                guardianID=parent['personID'],
                startDate=fake.date_between(start_date="-20y", end_date="-0y"),
                priority=1
            ))
relatives
# Out:
# [{'clubMemberID': 293, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 294, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 295, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 296, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 297, 'relativeID': 8, 'relationship': 'Friend'},
#  {'clubMemberID': 298, 'relativeID': 8, 'relationship': 'Friend'},
#  {'clubMemberID': 299, 'relativeID': 8, 'relationship': 'Friend'},
#  {'clubMemberID': 300, 'relativeID': 8, 'relationship': 'Friend'},
#  {'clubMemberID': 301, 'relativeID': 8, 'relationship': 'Friend'},
#  {'clubMemberID': 302, 'relativeID': 166, 'relationship': 'Partner'},
#  {'clubMemberID': 303, 'relativeID': 3, 'relationship': 'Mother'},
#  {'clubMemberID': 304, 'relativeID': 108, 'relationship': 'Mother'},
#  {'clubMemberID': 305, 'relativeID': 14, 'relationship': 'Friend'},
#  {'clubMemberID': 306, 'relativeID': 14, 'relationship': 'Friend'},
#  {'clubMemberID': 307, 'relativeID': 14, 'relationship': 'Father'},
#  {'clubMemberID': 308, 'relativeID': 14, 'relationship': 'Father'},
#  {'clubMemberID': 309, 'relativeID': 14, 'relationship': 'Father'},
#  {'clubMemberID': 310, 'relativeID': 14, 'relationship': 'Father'},
#  {'clubMemberID': 311, 'relativeID': 14, 'relationship': 'Father'},
#  {'clubMemberID': 312, 'relativeID': 32, 'relationship': 'Mother'},
#  {'clubMemberID': 313, 'relativeID': 32, 'relationship': 'Mother'},
#  {'clubMemberID': 314, 'relativeID': 164, 'relationship': 'Father'},
#  {'clubMemberID': 315, 'relativeID': 164, 'relationship': 'Father'},
#  {'clubMemberID': 316, 'relativeID': 52, 'relationship': 'Partner'},
#  {'clubMemberID': 317, 'relativeID': 17, 'relationship': 'Partner'},
#  {'clubMemberID': 318, 'relativeID': 17, 'relationship': 'Partner'},
#  {'clubMemberID': 319, 'relativeID': 17, 'relationship': 'Partner'},
#  {'clubMemberID': 320, 'relativeID': 17, 'relationship': 'Partner'},
#  {'clubMemberID': 321, 'relativeID': 9, 'relationship': 'Father'},
#  {'clubMemberID': 322, 'relativeID': 9, 'relationship': 'Father'},
#  {'clubMemberID': 323, 'relativeID': 9, 'relationship': 'Father'},
#  {'clubMemberID': 324, 'relativeID': 9, 'relationship': 'Father'},
#  {'clubMemberID': 325, 'relativeID': 127, 'relationship': 'Partner'},
#  {'clubMemberID': 326, 'relativeID': 127, 'relationship': 'Partner'},
#  {'clubMemberID': 327, 'relativeID': 127, 'relationship': 'Partner'},
#  {'clubMemberID': 328, 'relativeID': 127, 'relationship': 'Partner'},
#  {'clubMemberID': 329, 'relativeID': 127, 'relationship': 'Partner'},
#  {'clubMemberID': 330, 'relativeID': 40, 'relationship': 'Tutor'},
#  {'clubMemberID': 331, 'relativeID': 40, 'relationship': 'Tutor'},
#  {'clubMemberID': 332, 'relativeID': 116, 'relationship': 'Partner'},
#  {'clubMemberID': 333, 'relativeID': 114, 'relationship': 'Tutor'},
#  {'clubMemberID': 334, 'relativeID': 114, 'relationship': 'Tutor'},
#  {'clubMemberID': 335, 'relativeID': 114, 'relationship': 'Tutor'},
#  {'clubMemberID': 336, 'relativeID': 153, 'relationship': 'Mother'},
#  {'clubMemberID': 337, 'relativeID': 153, 'relationship': 'Mother'},
#  {'clubMemberID': 338, 'relativeID': 153, 'relationship': 'Mother'},
#  {'clubMemberID': 339, 'relativeID': 69, 'relationship': 'Friend'},
#  {'clubMemberID': 340, 'relativeID': 69, 'relationship': 'Friend'},
#  {'clubMemberID': 341, 'relativeID': 69, 'relationship': 'Friend'},
#  {'clubMemberID': 342, 'relativeID': 69, 'relationship': 'Friend'},
#  {'clubMemberID': 343, 'relativeID': 69, 'relationship': 'Friend'},
#  {'clubMemberID': 344, 'relativeID': 47, 'relationship': 'Tutor'},
#  {'clubMemberID': 345, 'relativeID': 47, 'relationship': 'Tutor'},
#  {'clubMemberID': 346, 'relativeID': 47, 'relationship': 'Tutor'},
#  {'clubMemberID': 347, 'relativeID': 123, 'relationship': 'Father'},
#  {'clubMemberID': 348, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 349, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 350, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 351, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 352, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 353, 'relativeID': 75, 'relationship': 'GrandMother'},
#  {'clubMemberID': 354, 'relativeID': 75, 'relationship': 'GrandMother'},
#  {'clubMemberID': 355, 'relativeID': 142, 'relationship': 'Friend'},
#  {'clubMemberID': 356, 'relativeID': 142, 'relationship': 'Friend'},
#  {'clubMemberID': 357, 'relativeID': 142, 'relationship': 'Friend'},
#  {'clubMemberID': 358, 'relativeID': 142, 'relationship': 'Friend'},
#  {'clubMemberID': 359, 'relativeID': 142, 'relationship': 'Friend'},
#  {'clubMemberID': 360, 'relativeID': 43, 'relationship': 'Tutor'},
#  {'clubMemberID': 361, 'relativeID': 87, 'relationship': 'Partner'},
#  {'clubMemberID': 362, 'relativeID': 87, 'relationship': 'Partner'},
#  {'clubMemberID': 363, 'relativeID': 87, 'relationship': 'Partner'},
#  {'clubMemberID': 364, 'relativeID': 87, 'relationship': 'Partner'},
#  {'clubMemberID': 365, 'relativeID': 87, 'relationship': 'Partner'},
#  {'clubMemberID': 366, 'relativeID': 66, 'relationship': 'Mother'},
#  {'clubMemberID': 367, 'relativeID': 66, 'relationship': 'Mother'},
#  {'clubMemberID': 368, 'relativeID': 139, 'relationship': 'Friend'},
#  {'clubMemberID': 369, 'relativeID': 139, 'relationship': 'Friend'},
#  {'clubMemberID': 370, 'relativeID': 154, 'relationship': 'GrandMother'},
#  {'clubMemberID': 371, 'relativeID': 154, 'relationship': 'GrandMother'},
#  {'clubMemberID': 372, 'relativeID': 155, 'relationship': 'Tutor'},
#  {'clubMemberID': 373, 'relativeID': 155, 'relationship': 'Tutor'},
#  {'clubMemberID': 374, 'relativeID': 155, 'relationship': 'Tutor'},
#  {'clubMemberID': 375, 'relativeID': 155, 'relationship': 'Tutor'},
#  {'clubMemberID': 376, 'relativeID': 155, 'relationship': 'Tutor'},
#  {'clubMemberID': 377, 'relativeID': 177, 'relationship': 'GrandMother'},
#  {'clubMemberID': 378, 'relativeID': 177, 'relationship': 'GrandMother'},
#  {'clubMemberID': 379, 'relativeID': 177, 'relationship': 'GrandMother'},
#  {'clubMemberID': 380, 'relativeID': 9, 'relationship': 'Partner'},
#  {'clubMemberID': 381, 'relativeID': 10, 'relationship': 'Mother'},
#  {'clubMemberID': 382, 'relativeID': 10, 'relationship': 'Mother'},
#  {'clubMemberID': 383, 'relativeID': 10, 'relationship': 'Mother'},
#  {'clubMemberID': 384, 'relativeID': 10, 'relationship': 'Mother'},
#  {'clubMemberID': 385, 'relativeID': 18, 'relationship': 'Mother'},
#  {'clubMemberID': 386, 'relativeID': 18, 'relationship': 'Mother'},
#  {'clubMemberID': 387, 'relativeID': 52, 'relationship': 'Father'},
#  {'clubMemberID': 388, 'relativeID': 52, 'relationship': 'Father'},
#  {'clubMemberID': 389, 'relativeID': 40, 'relationship': 'Friend'},
#  {'clubMemberID': 390, 'relativeID': 40, 'relationship': 'Friend'},
#  {'clubMemberID': 391, 'relativeID': 40, 'relationship': 'Friend'},
#  {'clubMemberID': 392, 'relativeID': 17, 'relationship': 'Mother'},
#  {'clubMemberID': 393, 'relativeID': 17, 'relationship': 'Mother'},
#  {'clubMemberID': 394, 'relativeID': 9, 'relationship': 'Tutor'},
#  {'clubMemberID': 395, 'relativeID': 29, 'relationship': 'Friend'},
#  {'clubMemberID': 396, 'relativeID': 29, 'relationship': 'Friend'},
#  {'clubMemberID': 397, 'relativeID': 100, 'relationship': 'Friend'},
#  {'clubMemberID': 398, 'relativeID': 100, 'relationship': 'Friend'},
#  {'clubMemberID': 399, 'relativeID': 100, 'relationship': 'Friend'},
#  {'clubMemberID': 400, 'relativeID': 147, 'relationship': 'Friend'},
#  {'clubMemberID': 401, 'relativeID': 147, 'relationship': 'Friend'},
#  {'clubMemberID': 402, 'relativeID': 147, 'relationship': 'Friend'},
#  {'clubMemberID': 403, 'relativeID': 147, 'relationship': 'Friend'},
#  {'clubMemberID': 404, 'relativeID': 115, 'relationship': 'Partner'},
#  {'clubMemberID': 405, 'relativeID': 115, 'relationship': 'Partner'},
#  {'clubMemberID': 406, 'relativeID': 115, 'relationship': 'Partner'},
#  {'clubMemberID': 407, 'relativeID': 115, 'relationship': 'Partner'},
#  {'clubMemberID': 408, 'relativeID': 115, 'relationship': 'Partner'},
#  {'clubMemberID': 409, 'relativeID': 123, 'relationship': 'Tutor'},
#  {'clubMemberID': 410, 'relativeID': 123, 'relationship': 'Tutor'},
#  {'clubMemberID': 411, 'relativeID': 123, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 123, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 66, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 142, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 47, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 75, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 127, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 10, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 108, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 17, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 40, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 164, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 19, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 87, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 108, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 114, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 138, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 19, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 87, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 40, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 172, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 75, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 142, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 18, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 127, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 40, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 153, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 19, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 108, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 123, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 19, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 123, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 153, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 108, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 177, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 172, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 138, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 139, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 97, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 32, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 87, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 8, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 52, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 97, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 100, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 87, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 14, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 160, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 10, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 87, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 168, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 10, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 52, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 100, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 87, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 114, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 168, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 168, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 19, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 153, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 29, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 43, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 87, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 97, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 52, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 116, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 168, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 75, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 75, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 10, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 168, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 14, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 17, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 108, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 123, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 75, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 8, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 18, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 153, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 43, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 164, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 116, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 52, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 114, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 8, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 52, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 138, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 14, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 138, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 29, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 100, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 14, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 114, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 116, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 47, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 87, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 138, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 17, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 115, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 100, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 14, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 139, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 154, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 87, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 40, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 177, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 147, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 69, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 100, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 127, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 168, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 154, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 19, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 160, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 127, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 3, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 168, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 142, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 116, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 114, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 115, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 138, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 123, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 87, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 172, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 114, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 19, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 17, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 123, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 29, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 153, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 32, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 168, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 14, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 97, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 32, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 90, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 47, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 108, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 90, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 139, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 66, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 8, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 43, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 75, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 75, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 14, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 100, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 139, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 69, 'relationship': 'GrandFather'},
#  {'clubMemberID': 412, 'relativeID': 17, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 3, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 142, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 153, 'relationship': 'Mother'},
#  {'clubMemberID': 412, 'relativeID': 9, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 66, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 114, 'relationship': 'Friend'},
#  {'clubMemberID': 412, 'relativeID': 168, 'relationship': 'Tutor'},
#  {'clubMemberID': 412, 'relativeID': 155, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 90, 'relationship': 'Father'},
#  {'clubMemberID': 412, 'relativeID': 75, 'relationship': 'GrandMother'},
#  {'clubMemberID': 412, 'relativeID': 18, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 69, 'relationship': 'Partner'},
#  {'clubMemberID': 412, 'relativeID': 69, 'relationship': 'Partner'}]

# %%
events = []
teams = []
teamMembers = []
for date in pd.date_range("2024-07-01 7:00:00", "2024-08-15", freq="8h"):
    home = fake.random.choice(locations)
    visit = fake.random.choice(locations)
    if home["locationID"] == visit["locationID"]:
        continue

    ok = True
    for team in (home, visit):
        pers = pd.DataFrame(personnel)
        pers = pers[pers.role == "Trainer"]
        pers = pers[pers.locationID == team["locationID"]]
        pers = pers[pers.endDate.isna()]
        pers = pers.personID.unique()
        ok &= len(pers) > 0

    if not ok:
        continue

    homeTeam = dict(
        teamID=len(teams) + 1,
        locationID=home["locationID"],
        name=("Team " + fake.word()).title(),
        gender=fake.random.choice(("m", "f")),
    )
    visitTeam = dict(
        teamID=len(teams) + 2,
        locationID=home["locationID"],
        name=("Team " + fake.word()).title(),
        gender=fake.random.choice(("m", "f")),
    )
    event = dict(
        homeTeamID=homeTeam["teamID"],
        visitTeamID=visitTeam["teamID"],
        date=date,
        address=fake.address(),
        type=fake.random.choice(("training", "game")),
        homeScore=None,
        visitingScore=None,
    )
    if date < pd.to_datetime("now"):
        event["homeScore"] = fake.random_int(0, 10)
        event["visitingScore"] = fake.random_int(0, 10)
    teams.extend((homeTeam, visitTeam))
    events.append(event)
    for team in (homeTeam, visitTeam):
        # choose members
        candidates = pd.DataFrame(memberLocations).merge(
            pd.DataFrame(persons), on="personID"
        )
        candidates = candidates[candidates.locationID == team["locationID"]]
        candidates = candidates[candidates.gender == team["gender"]]
        candidates = candidates[candidates.dateOfBirth < "2015"]
        candidates = candidates[candidates.endDate.isna()].personID.unique()
        for i, canID in enumerate(candidates[:12]):
            teamMembers.append(
                dict(
                    teamID=team["teamID"],
                    personID=canID,
                    startDate=date,
                    endDate=pd.NaT,
                    isCaptain=i == 0,
                    role=fake.random.choice(
                        ("goalkeeper", "defender", "midfielder", "forward", "other")
                    ),
                )
            )
        pers = pd.DataFrame(personnel)
        pers = pers[pers.role == "Trainer"]
        pers = pers[pers.locationID == team["locationID"]]
        pers = pers[pers.endDate.isna()]
        pers = pers.personID.unique()

        teamMembers.append(
            dict(
                teamID=team["teamID"],
                personID=pers[0],
                startDate=date,
                endDate=pd.NaT,
                role="coach",
                isCaptain=False,
            )
        )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\drewa\OneDrive\Documents\School\COMP353\GroupProject\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 26
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 5
#       3 teamMembers = []
#       4 for date in pd.date_range("2024-07-01 7:00:00", "2024-08-15", freq="8h"):
# ----> 5     home = fake.random.choice(locations)
#       6     visit = fake.random.choice(locations)
#       7     if home["locationID"] == visit["locationID"]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\random.py:348, in Random.choice(self, seq)
#     346 if not len(seq):
#     347     raise IndexError('Cannot choose from an empty sequence')
# --> 348 return seq[self._randbelow(len(seq))]
#
# File c:\Users\drewa\OneDrive\Documents\School\COMP353\GroupProject\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\drewa\OneDrive\Documents\School\COMP353\GroupProject\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 26

# %%
locations = pd.DataFrame(locations)
persons = pd.DataFrame(persons)
personnel = pd.DataFrame(personnel)

clubmember_relatives = pd.DataFrame(relatives).drop_duplicates(subset=['clubMemberID', 'relativeID'])
clubmember_guardians = pd.DataFrame(clubMembers).drop_duplicates(subset=['clubMemberID', 'guardianID', 'startDate'])
family_clubmember_location = pd.DataFrame(memberLocations).drop_duplicates(subset=['personID', 'locationID', 'startDate'])

scheduled_events = pd.DataFrame(events)
teams = pd.DataFrame(teams)
team_members = pd.DataFrame(teamMembers).drop_duplicates(subset=['teamID', 'personID'])

# %%
from sqlalchemy import create_engine, text
import glob

# Initialize database connection
engine = create_engine(database_uri, echo=True)

# with engine.begin() as conn:
#     # Run each migration in order to create tables if they don't exist
#     for path in sorted(glob.glob('migrations/*.sql')):
#         with open(path) as f:
#             sql = f.read()
#             conn.execute(text(sql))

with engine.begin() as conn:
    # Delete data and reset auto-increment ids.
    conn.execute(text("SET FOREIGN_KEY_CHECKS = 0;"))
    conn.execute(text("TRUNCATE TABLE ClubMember_Guardians;"))
    conn.execute(text("TRUNCATE TABLE ClubMember_Relatives;"))
    # conn.execute(text("TRUNCATE TABLE Email_Log;"))
    conn.execute(text("TRUNCATE TABLE Family_ClubMember_Location;"))
    conn.execute(text("TRUNCATE TABLE Locations;"))
    conn.execute(text("TRUNCATE TABLE Personnel;"))
    conn.execute(text("TRUNCATE TABLE Persons;"))
    conn.execute(text("TRUNCATE TABLE Scheduled_Events;"))
    conn.execute(text("TRUNCATE TABLE Team_Members;"))
    conn.execute(text("TRUNCATE TABLE Teams;"))
    conn.execute(text("SET FOREIGN_KEY_CHECKS = 1;"))

    # Populate tables with generated data
    persons.to_sql("Persons", con=conn, if_exists="append", index=False, method="multi")
    locations.to_sql(
        "Locations", con=conn, if_exists="append", index=False, method="multi"
    )
    clubmember_relatives.to_sql(
        "ClubMember_Relatives",
        con=conn,
        if_exists="append",
        index=False,
        method="multi",
    )
    clubmember_guardians.to_sql(
        "ClubMember_Guardians",
        con=conn,
        if_exists="append",
        index=False,
        method="multi",
    )
    family_clubmember_location.to_sql(
        "Family_ClubMember_Location",
        con=conn,
        if_exists="append",
        index=False,
        method="multi",
    )
    personnel.to_sql(
        "Personnel", con=conn, if_exists="append", index=False, method="multi"
    )
    teams.to_sql("Teams", con=conn, if_exists="append", index=False, method="multi")
    team_members.to_sql(
        "Team_Members", con=conn, if_exists="append", index=False, method="multi"
    )
    scheduled_events.to_sql(
        "Scheduled_Events", con=conn, if_exists="append", index=False, method="multi"
    )
# Out:
# 2024-08-03 10:13:04,340 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-08-03 10:13:04,342 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:04,371 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-08-03 10:13:04,373 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:04,394 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-08-03 10:13:04,396 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:04,438 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-03 10:13:04,439 INFO sqlalchemy.engine.Engine SET FOREIGN_KEY_CHECKS = 0;
# 2024-08-03 10:13:04,441 INFO sqlalchemy.engine.Engine [generated in 0.00146s] ()
# 2024-08-03 10:13:04,456 INFO sqlalchemy.engine.Engine TRUNCATE TABLE ClubMember_Guardians;
# 2024-08-03 10:13:04,458 INFO sqlalchemy.engine.Engine [generated in 0.00157s] ()
# 2024-08-03 10:13:04,503 INFO sqlalchemy.engine.Engine TRUNCATE TABLE ClubMember_Relatives;
# 2024-08-03 10:13:04,504 INFO sqlalchemy.engine.Engine [generated in 0.00159s] ()
# 2024-08-03 10:13:04,541 INFO sqlalchemy.engine.Engine TRUNCATE TABLE Family_ClubMember_Location;
# 2024-08-03 10:13:04,542 INFO sqlalchemy.engine.Engine [generated in 0.00122s] ()
# 2024-08-03 10:13:04,581 INFO sqlalchemy.engine.Engine TRUNCATE TABLE Locations;
# 2024-08-03 10:13:04,583 INFO sqlalchemy.engine.Engine [generated in 0.00206s] ()
# 2024-08-03 10:13:04,620 INFO sqlalchemy.engine.Engine TRUNCATE TABLE Personnel;
# 2024-08-03 10:13:04,622 INFO sqlalchemy.engine.Engine [generated in 0.00210s] ()
# 2024-08-03 10:13:04,668 INFO sqlalchemy.engine.Engine TRUNCATE TABLE Persons;
# 2024-08-03 10:13:04,670 INFO sqlalchemy.engine.Engine [generated in 0.00211s] ()
# 2024-08-03 10:13:04,714 INFO sqlalchemy.engine.Engine TRUNCATE TABLE Scheduled_Events;
# 2024-08-03 10:13:04,717 INFO sqlalchemy.engine.Engine [generated in 0.00340s] ()
# 2024-08-03 10:13:04,756 INFO sqlalchemy.engine.Engine TRUNCATE TABLE Team_Members;
# 2024-08-03 10:13:04,758 INFO sqlalchemy.engine.Engine [generated in 0.00179s] ()
# 2024-08-03 10:13:04,793 INFO sqlalchemy.engine.Engine TRUNCATE TABLE Teams;
# 2024-08-03 10:13:04,795 INFO sqlalchemy.engine.Engine [generated in 0.00118s] ()
# 2024-08-03 10:13:04,834 INFO sqlalchemy.engine.Engine SET FOREIGN_KEY_CHECKS = 1;
# 2024-08-03 10:13:04,836 INFO sqlalchemy.engine.Engine [generated in 0.00174s] ()
# 2024-08-03 10:13:04,862 INFO sqlalchemy.engine.Engine DESCRIBE `tnc353_1`.`Persons`
# 2024-08-03 10:13:04,865 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,040 INFO sqlalchemy.engine.Engine INSERT INTO `Persons` (`personID`, `firstName`, `lastName`, `emailAddress`, `telephoneNumber`, `dateOfBirth`, gender, `medicareCardNumber`, sin, `civicNumber`, province, `postalCode`, city) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s ...
# 2024-08-03 10:13:05,041 INFO sqlalchemy.engine.Engine [no key 0.01489s] (1, 'Alexander', 'Huang', 'ylee@example.com', '5145559561', datetime.datetime(2006, 9, 30, 0, 0), 'f', 'AjGC96923724822', '035285717', '915', 'QC', 'H4X3N5', 'Montreal', 2, 'Rachel', 'Robinson', 'jacquelineallison@example.com', '5145557869', datetime.datetime(1964, 1, 29, 0, 0), 'm', 'mknK21148604497', '180462319', '6493', 'QC', 'J9A1L4', 'Montreal', 3, 'Teresa', 'Mccormick', 'anorton@example.org', '5145559589', datetime.datetime(1987, 6, 1, 0, 0), 'f', 'evaJ03603366495', '761160522', '79226', 'QC', 'G1N3B1', 'Montreal', 4, 'Brooke', 'Tucker', 'john62@example.com', '5145556093', datetime.datetime(1976, 5, 9, 0, 0), 'm', 'oUzn71534146117', '677501827', '00611', 'QC' ... 5256 parameters truncated ... 'Smith', 'wagnermaria@example.com', '5145551954', datetime.datetime(2015, 4, 30, 0, 0), 'm', 'qkXb42847719172', '047227665', '88349', 'QC', 'J8G6K7', 'Châteauguay', 410, 'Maria', 'Thompson', 'wagnermaria@example.com', '5145551954', datetime.datetime(2013, 8, 4, 0, 0), 'f', 'DxMp72135711559', '657051827', '88349', 'QC', 'J8G6K7', 'Châteauguay', 411, 'Christopher', 'Carrillo', 'wagnermaria@example.com', '5145551954', datetime.datetime(2019, 8, 6, 0, 0), 'm', 'wmjC86279351657', '721407666', '88349', 'QC', 'J8G6K7', 'Châteauguay', 412, 'Paula', 'Foster', 'wagnermaria@example.com', '5145551954', datetime.datetime(2016, 6, 17, 0, 0), 'f', 'ZfIN44864081191', '170182687', '88349', 'QC', 'J8G6K7', 'Châteauguay')
# 2024-08-03 10:13:05,142 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `tnc353_1`
# 2024-08-03 10:13:05,144 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,160 INFO sqlalchemy.engine.Engine DESCRIBE `tnc353_1`.`Locations`
# 2024-08-03 10:13:05,161 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,190 INFO sqlalchemy.engine.Engine INSERT INTO `Locations` (`locationID`, `phoneNumber`, `civicNumber`, province, `postalCode`, city, capacity, name, `webAddress`, type) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# 2024-08-03 10:13:05,192 INFO sqlalchemy.engine.Engine [no key 0.00241s] (1, '5145550016', '9054', 'QC', 'J9T8X3', 'Montreal', 112, 'Montreal Soccer Club', 'montreal.yscm.ca', 'Branch', 2, '5145552841', '11926', 'QC', 'H4T1A2', 'Quebec City', 281, 'Quebec City Soccer Club', 'quebec-city.yscm.ca', 'Branch', 3, '5145558262', '89089', 'QC', 'H1J7B6', 'Laval', 209, 'Laval Soccer Club', 'laval.yscm.ca', 'Branch', 4, '5145557912', '6757', 'QC', 'H7E3R1', 'Gatineau', 807, 'Gatineau Soccer Club', 'gatineau.yscm.ca', 'Branch', 5, '5145556973', '309', 'QC', 'G4M4J7', 'Longueuil', 698, 'Longueuil Soccer Club', 'longueuil.yscm.ca', 'Branch' ... 200 parameters truncated ... 26, '5145554745', '25445', 'QC', 'H5S1M3', "Val-d'Or", 266, "Val-d'Or Soccer Club", 'val-dor.yscm.ca', 'Branch', 27, '5145554418', '26801', 'QC', 'J7S6Y4', 'Rouyn-Noranda', 529, 'Rouyn-Noranda Soccer Club', 'rouyn-noranda.yscm.ca', 'Branch', 28, '5145557539', '05590', 'QC', 'J8V7G9', 'Sorel-Tracy', 474, 'Sorel-Tracy Soccer Club', 'sorel-tracy.yscm.ca', 'Branch', 29, '5145551390', '4024', 'QC', 'G9V5S8', 'Boucherville', 357, 'Boucherville Soccer Club', 'boucherville.yscm.ca', 'Branch', 30, '5145553306', '04318', 'QC', 'J5A7S5', 'Salaberry-de-Valleyfield', 384, 'Salaberry-de-Valleyfield Soccer Club', 'salaberry-de-valleyfield.yscm.ca', 'Branch')
# 2024-08-03 10:13:05,217 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `tnc353_1`
# 2024-08-03 10:13:05,218 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,241 INFO sqlalchemy.engine.Engine DESCRIBE `tnc353_1`.`ClubMember_Relatives`
# 2024-08-03 10:13:05,243 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,277 INFO sqlalchemy.engine.Engine INSERT INTO `ClubMember_Relatives` (`clubMemberID`, `relativeID`, relationship) VALUES (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s)
# 2024-08-03 10:13:05,279 INFO sqlalchemy.engine.Engine [no key 0.00235s] (293, 168, 'Father', 294, 168, 'Father', 295, 168, 'Father', 296, 168, 'Father', 297, 8, 'Friend', 298, 8, 'Friend', 299, 8, 'Friend', 300, 8, 'Friend', 301, 8, 'Friend', 302, 166, 'Partner', 303, 3, 'Mother', 304, 108, 'Mother', 305, 14, 'Friend', 306, 14, 'Friend', 307, 14, 'Father', 308, 14, 'Father', 309, 14 ... 374 parameters truncated ... 97, 'Father', 412, 32, 'Friend', 412, 8, 'GrandFather', 412, 52, 'Partner', 412, 100, 'GrandFather', 412, 14, 'Father', 412, 160, 'Friend', 412, 29, 'GrandMother', 412, 43, 'Tutor', 412, 116, 'Tutor', 412, 115, 'Tutor', 412, 154, 'Partner', 412, 147, 'Friend', 412, 69, 'Father', 412, 3, 'GrandMother', 412, 90, 'Tutor', 412, 155, 'GrandMother')
# 2024-08-03 10:13:05,308 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `tnc353_1`
# 2024-08-03 10:13:05,309 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,327 INFO sqlalchemy.engine.Engine DESCRIBE `tnc353_1`.`ClubMember_Guardians`
# 2024-08-03 10:13:05,329 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,360 INFO sqlalchemy.engine.Engine INSERT INTO `ClubMember_Guardians` (`clubMemberID`, `guardianID`, `startDate`, priority) VALUES (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s)
# 2024-08-03 10:13:05,362 INFO sqlalchemy.engine.Engine [no key 0.00326s] (293, 168, datetime.date(2014, 6, 27), 0, 294, 168, datetime.date(2014, 6, 27), 0, 295, 168, datetime.date(2014, 6, 27), 0, 296, 168, datetime.date(2014, 6, 27), 0, 297, 8, datetime.date(2012, 7, 3), 0, 298, 8, datetime.date(2012, 7, 3), 0, 299, 8, datetime.date(2012, 7, 3), 0, 300, 8, datetime.date(2012, 7, 3), 0, 301, 8, datetime.date(2012, 7, 3), 0, 302, 166, datetime.date(2021, 4, 24), 0, 303, 3, datetime.date(2016, 12, 6), 0, 304, 108, datetime.date(2008, 12, 30), 0, 305, 14 ... 572 parameters truncated ... datetime.date(2021, 7, 5), 1, 412, 3, datetime.date(2023, 11, 4), 1, 412, 9, datetime.date(2023, 4, 27), 1, 412, 115, datetime.date(2007, 9, 13), 1, 412, 123, datetime.date(2023, 11, 29), 1, 412, 29, datetime.date(2005, 9, 30), 1, 412, 168, datetime.date(2023, 4, 20), 1, 412, 97, datetime.date(2016, 10, 2), 1, 412, 90, datetime.date(2008, 10, 2), 1, 412, 8, datetime.date(2006, 11, 27), 1, 412, 17, datetime.date(2014, 10, 14), 1, 412, 3, datetime.date(2006, 4, 4), 1, 412, 66, datetime.date(2008, 1, 9), 1)
# 2024-08-03 10:13:05,412 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `tnc353_1`
# 2024-08-03 10:13:05,413 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,439 INFO sqlalchemy.engine.Engine DESCRIBE `tnc353_1`.`Family_ClubMember_Location`
# 2024-08-03 10:13:05,440 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,473 INFO sqlalchemy.engine.Engine INSERT INTO `Family_ClubMember_Location` (`personID`, `locationID`, `startDate`, `endDate`) VALUES (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s), (%s, %s, %s, %s)
# 2024-08-03 10:13:05,474 INFO sqlalchemy.engine.Engine [no key 0.00373s] (19, 3, datetime.date(2011, 9, 19), None, 168, 29, datetime.date(2014, 6, 27), None, 293, 29, datetime.date(2014, 6, 27), None, 294, 29, datetime.date(2014, 6, 27), None, 295, 29, datetime.date(2014, 6, 27), None, 296, 29, datetime.date(2014, 6, 27), None, 8, 1, datetime.date(2012, 7, 3), None, 297, 1, datetime.date(2012, 7, 3), None, 298, 1, datetime.date(2012, 7, 3), None, 299, 1, datetime.date(2012, 7, 3), None, 300, 1, datetime.date(2012, 7, 3), None, 301, 1, datetime.date(2012, 7, 3), None, 90, 15 ... 540 parameters truncated ... datetime.date(2020, 12, 4), None, 403, 25, datetime.date(2020, 12, 4), None, 115, 19, datetime.date(2013, 9, 10), None, 404, 19, datetime.date(2013, 9, 10), None, 405, 19, datetime.date(2013, 9, 10), None, 406, 19, datetime.date(2013, 9, 10), None, 407, 19, datetime.date(2013, 9, 10), None, 408, 19, datetime.date(2013, 9, 10), None, 409, 21, datetime.date(2008, 2, 15), None, 410, 21, datetime.date(2008, 2, 15), None, 411, 21, datetime.date(2008, 2, 15), None, 412, 21, datetime.date(2008, 2, 15), None, 172, 30, datetime.date(2007, 5, 23), None)
# 2024-08-03 10:13:05,523 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `tnc353_1`
# 2024-08-03 10:13:05,525 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,557 INFO sqlalchemy.engine.Engine DESCRIBE `tnc353_1`.`Personnel`
# 2024-08-03 10:13:05,558 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,610 INFO sqlalchemy.engine.Engine INSERT INTO `Personnel` (`locationID`, `personID`, `startDate`, `endDate`, `role`, mandate, `isGeneralManager`) VALUES (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s, %s, %s, %s), (%s, %s, %s, %s,  ...
# 2024-08-03 10:13:05,612 INFO sqlalchemy.engine.Engine [no key 0.00697s] (1, 1, datetime.date(2017, 2, 5), None, 'Administrator', 'Salary', 1, 1, 2, datetime.date(2014, 6, 4), None, 'Other', 'Salary', 0, 1, 3, datetime.date(2016, 12, 6), None, 'Administrator', 'Salary', 0, 1, 4, datetime.date(2006, 11, 8), None, 'Other', 'Volunteer', 0, 1, 5, datetime.date(2016, 8, 9), None, 'Trainer', 'Salary', 0, 1, 6, datetime.date(2012, 2, 3), None, 'Administrator', 'Salary', 0, 1, 7, datetime.date(2004, 11, 3), None, 'Trainer', 'Volunteer', 0, 1 ... 1146 parameters truncated ... 0, 30, 172, datetime.date(2007, 5, 23), None, 'Administrator', 'Salary', 1, 30, 173, datetime.date(2019, 12, 9), None, 'Trainer', 'Salary', 0, 30, 174, datetime.date(2018, 11, 30), None, 'Trainer', 'Volunteer', 0, 30, 175, datetime.date(2013, 6, 8), None, 'Trainer', 'Volunteer', 0, 30, 176, datetime.date(2017, 8, 27), None, 'Trainer', 'Salary', 0, 30, 177, datetime.date(2007, 8, 22), None, 'Administrator', 'Salary', 0, 30, 178, datetime.date(2018, 1, 5), None, 'Administrator', 'Volunteer', 0)
# 2024-08-03 10:13:05,668 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `tnc353_1`
# 2024-08-03 10:13:05,669 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,687 INFO sqlalchemy.engine.Engine DESCRIBE `tnc353_1`.`Teams`
# 2024-08-03 10:13:05,689 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,708 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `tnc353_1`
# 2024-08-03 10:13:05,710 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,730 INFO sqlalchemy.engine.Engine DESCRIBE `tnc353_1`.`Team_Members`
# 2024-08-03 10:13:05,732 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,748 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `tnc353_1`
# 2024-08-03 10:13:05,749 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,765 INFO sqlalchemy.engine.Engine DESCRIBE `tnc353_1`.`Scheduled_Events`
# 2024-08-03 10:13:05,767 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,782 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `tnc353_1`
# 2024-08-03 10:13:05,784 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-03 10:13:05,798 INFO sqlalchemy.engine.Engine COMMIT
